# %% [markdown]
# ## Датасет собран из базы данных переписи 1994 года и содержит данные о доходах.
# ### Информация о данных:
# * age: continuous.
# * workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# * fnlwgt: continuous.
# * education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, * Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# * education-num: continuous.
# * marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# * occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# * relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# * race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# * sex: Female, Male.
# * capital-gain: continuous.
# * capital-loss: continuous.
# * hours-per-week: continuous.
# * native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# * salary: >50K,<=50K
#
# ## Проведите анализ данных при помощи Pandas выполнив поставленные задачи.
# ####

# %%
import pandas as pd

# %%
# загружаем датасет
data = pd.read_csv("./data/adult.data.csv")
data.head(10)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
# 5   37           Private  284582    Masters             14
# 6   49           Private  160187        9th              5
# 7   52  Self-emp-not-inc  209642    HS-grad              9
# 8   31           Private   45781    Masters             14
# 9   42           Private  159449  Bachelors             13
#
#           marital-status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2               Divorced  Handlers-cleaners  Not-in-family  White    Male
# ...

# %% [markdown]
# **1. Посчитайте, сколько мужчин и женщин (признак *sex*) представлено в этом датасете**

# %%
data["sex"].value_counts()
# Out:
# sex
# Male      21790
# Female    10771
# Name: count, dtype: int64

# %% [markdown]
# **2. Каков средний возраст мужчин (признак *age*) по всему датасету?**

# %%
avg_male_age = data.loc[data['sex'] == 'Male', 'age'].mean()
print(f"Average male age: {int(avg_male_age)}")
# Out:
# Average male age: 39

# %% [markdown]
# **3. Какова доля граждан Соединенных Штатов (признак *native-country*)?**

# %%
# Доли всех стран
countries_share = data['native-country'].value_counts(normalize=True)

# Только США
usa_share = countries_share['United-States']

print(f"USA natives: {usa_share:.2%}")
# Out:
# USA natives: 89.59%

# %% [markdown]
# **4-5. Рассчитайте среднее значение и среднеквадратичное отклонение возраста тех, кто получает более 50K в год (признак *salary*) и тех, кто получает менее 50K в год**

# %%
statistics = data.groupby('salary')['age'].agg(['mean', 'std'])

print(statistics.round(3))
# Out:
#           mean     std
# salary
# <=50K   36.784  14.020
# >50K    44.250  10.519

# %% [markdown]
# **6. Правда ли, что люди, которые получают больше 50k, имеют минимум высшее образование? (признак *education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters* или *Doctorate*)**

# %%
higher_edu = ['Bachelors','Prof-school', 'Assoc-acdm', 'Assoc-voc', 'Masters', 'Doctorate']
rich_eduction = data.loc[data['salary'] == '>50K','education']
is_true = rich_eduction.isin(higher_edu).all()
print(f"Rich people - higher education?: {is_true}")

# Показать уникальные виды образования среди тех, кто зарабатывает >50K
print(f"Other education: {data.loc[data['salary'] == '>50K', 'education'].unique()}")
# Out:
# Rich people - higher education?: False
# Other education: ['HS-grad' 'Masters' 'Bachelors' 'Some-college' 'Assoc-voc' 'Doctorate'
#  'Prof-school' 'Assoc-acdm' '7th-8th' '12th' '10th' '11th' '9th' '5th-6th'
#  '1st-4th']

# %% [markdown]
# **7. Выведите статистику возраста для каждой расы (признак *race*) и каждого пола. Используйте *groupby* и *describe*. Найдите таким образом максимальный возраст мужчин расы *Asian-Pac-Islander*.**

# %%
# Группируем по двум колонкам и берем статистику возраста
age_by_race_sex_statistics = data.groupby(['race', 'sex'])['age'].describe()
print(age_by_race_sex_statistics)

max_age_asian_male = age_by_race_sex_statistics.loc[('Asian-Pac-Islander', 'Male'), 'max']
print(f"Max age: {max_age_asian_male}")
# Out:
#                              count       mean        std   min   25%   50%  \
# race               sex
# Amer-Indian-Eskimo Female    119.0  37.117647  13.114991  17.0  27.0  36.0
#                    Male      192.0  37.208333  12.049563  17.0  28.0  35.0
# Asian-Pac-Islander Female    346.0  35.089595  12.300845  17.0  25.0  33.0
#                    Male      693.0  39.073593  12.883944  18.0  29.0  37.0
# Black              Female   1555.0  37.854019  12.637197  17.0  28.0  37.0
#                    Male     1569.0  37.682600  12.882612  17.0  27.0  36.0
# Other              Female    109.0  31.678899  11.631599  17.0  23.0  29.0
#                    Male      162.0  34.654321  11.355531  17.0  26.0  32.0
# White              Female   8642.0  36.811618  14.329093  17.0  25.0  35.0
#                    Male    19174.0  39.652498  13.436029  17.0  29.0  38.0
#
#                              75%   max
# race               sex
# Amer-Indian-Eskimo Female  46.00  80.0
# ...

# %% [markdown]
# **8. Среди кого больше доля зарабатывающих много (>50K): среди женатых или холостых мужчин (признак *marital-status*)? Женатыми считаем тех, у кого *marital-status* начинается с *Married* (Married-civ-spouse, Married-spouse-absent или Married-AF-spouse), остальных считаем холостыми.**

# %%
men_only = data[data['sex'] == 'Male'].copy()

#Создаем признак через лямбда-функцию
men_only['is_married'] = men_only['marital-status'].apply(lambda x: 'Married' if x.startswith('Married') else 'Single')

wealth_share = men_only.groupby('is_married')['salary'].value_counts(normalize=True)
print(wealth_share)

married_share = wealth_share['Married', '>50K']
single_share = wealth_share['Single', '>50K']

if married_share > single_share:
    print("More rich married men")
else:
    print("More rich single men")
# Out:
# is_married  salary
# Married     <=50K     0.559486
#             >50K      0.440514
# Single      <=50K     0.915505
#             >50K      0.084495
# Name: proportion, dtype: float64
# More rich married men

# %% [markdown]
# **9. Какое максимальное число часов человек работает в неделю (признак *hours-per-week*)? Сколько людей работают такое количество часов и каков среди них процент зарабатывающих много?**

# %%
# Максимум часов в неделю
max_hours = data['hours-per-week'].max()
print(f"Max hours per week: {max_hours}")

# Выбираем работяг, которые работают максимум часов в неделю
workers_max_hours = data.loc[data['hours-per-week'] == max_hours]

# Считаем количесство бедолаг
count_workers_max_hours = len(workers_max_hours)
print(f"Workers count who work max hours per week: {count_workers_max_hours}")

# Доля богатых (>50K) бедолаг
rich_workers_share = workers_max_hours['salary'].value_counts(normalize=True)
print(rich_workers_share)
# Out:
# 99
# 85
# salary
# <=50K    0.705882
# >50K     0.294118
# Name: proportion, dtype: float64

# %% [markdown]
# **10. Посчитайте среднее время работы (*hours-per-week*) зарабатывающих мало и много (*salary*) для каждой страны (*native-country*).**

# %%
income = data.groupby(['native-country','salary'])['hours-per-week'].mean().unstack()
print(income)
# Out:
# salary                          <=50K       >50K
# native-country
# ?                           40.164760  45.547945
# Cambodia                    41.416667  40.000000
# Canada                      37.914634  45.641026
# China                       37.381818  38.900000
# Columbia                    38.684211  50.000000
# Cuba                        37.985714  42.440000
# Dominican-Republic          42.338235  47.000000
# Ecuador                     38.041667  48.750000
# El-Salvador                 36.030928  45.000000
# England                     40.483333  44.533333
# France                      41.058824  50.750000
# Germany                     39.139785  44.977273
# Greece                      41.809524  50.625000
# Guatemala                   39.360656  36.666667
# Haiti                       36.325000  42.750000
# Holand-Netherlands          40.000000        NaN
# Honduras                    34.333333  60.000000
# Hong                        39.142857  45.000000
# ...

# %% [markdown]
# **11.Сгруппируйте людей по возрастным группам *young*, *adult*, *retiree*, где:**
# * *young* соответствует 16-35 лет
# * *adult* - 35-70 лет
# * *retiree* - 70-100 лет
#
# **Проставьте название соответсвтуещей группы для каждого человека в новой колонке AgeGroup**

# %%
# (16, 34] - young
bins = [16, 34, 70, 100]
labels = ['young', 'adult', 'retiree']

# include_lowest - чтобы включить 16-летних
data['AgeGroup'] = pd.cut(data['age'], bins=bins, labels=labels, include_lowest=True)

print(data[['age', 'AgeGroup']])
# Out:
#        age AgeGroup
# 0       39    adult
# 1       50    adult
# 2       38    adult
# 3       53    adult
# 4       28    young
# ...    ...      ...
# 32556   27    young
# 32557   40    adult
# 32558   58    adult
# 32559   22    young
# 32560   52    adult
#
# [32561 rows x 2 columns]

# %% [markdown]
# **12-13. Определите количество зарабатывающих >50K в каждой из возрастных групп (колонка AgeGroup), а также выведите название возрастной группы, в которой чаще зарабатывают больше 50К (>50K)**

# %%
rich = data[data['salary'] == '>50K']
rich_age_groups = rich.groupby('AgeGroup', observed=False).size()

print(f"Age groups that make >50K:\n{rich_age_groups}")

name_rich_age_group = data.groupby('AgeGroup', observed=False)['salary'].value_counts(normalize=True)
max_rich = name_rich_age_group.loc[:,'>50K'].idxmax()
print(max_rich)
# Out:
# Age groups that make >50K:
# AgeGroup
# young      1488
# adult      6259
# retiree      94
# dtype: int64
# adult

# %% [markdown]
# **14. Сгруппируйте людей по типу занятости (колонка occupation) и определите количество людей в каждой группе. После чего напишите функциюю фильтрации filter_func, которая будет возвращать только те группы, в которых средний возраст (колонка age) не больше 40 и в которых все работники отрабатывают более 5 часов в неделю (колонка hours-per-week)**

# %%
occupation_groups = data.groupby('occupation')
print(f"Count: {occupation_groups.size()}")

def filter_func(group_to_filter):
    ave_age = group_to_filter['age'].mean() <= 40
    all_work_enough = (group_to_filter['hours-per-week'] > 5).all()

    return ave_age and all_work_enough

filtered_data = occupation_groups.filter(filter_func)
print(filtered_data['occupation'].unique())
# Out:
# Count: occupation
# ?                    1843
# Adm-clerical         3770
# Armed-Forces            9
# Craft-repair         4099
# Exec-managerial      4066
# Farming-fishing       994
# Handlers-cleaners    1370
# Machine-op-inspct    2002
# Other-service        3295
# Priv-house-serv       149
# Prof-specialty       4140
# Protective-serv       649
# Sales                3650
# Tech-support          928
# Transport-moving     1597
# dtype: int64
# ['Armed-Forces']
